# %%
import pandas as pd
import numpy as np
df=pd.read_csv("F:\EU_MRV_Publication_of_information.csv")
df.head(10)
# Out:
#    IMO Number           Name           Ship type  Reporting Period  \
# 0     5383304        ASTORIA      Passenger ship              2019
# 1     6417097     MARCO POLO      Passenger ship              2019
# 2     6511128     RED STAR 1         Ro-pax ship              2019
# 3     6602898  OCEAN MAJESTY      Passenger ship              2019
# 4     6703343       EQUALITY    Other ship types              2019
# 5     7022356          KENOZ  General cargo ship              2019
# 6     7037806    IONIAN STAR         Ro-pax ship              2019
# 7     7043843          TALOS          Ro-ro ship              2019
# 8     7128332       SEA WIND         Ro-pax ship              2019
# 9     7128887      ST DAMIAN         Ro-pax ship              2019
#
#      Technical efficiency Port of Registry Home Port Ice Class DoC issue date  \
# 0  EIV (169.16 gCO₂/t·nm)              NaN       NaN       NaN     15-03-2020
# ...

# %%
df.shape
# Out:
# (12204, 62)

# %%
df.columns
# Out:
# Index(['IMO Number', 'Name', 'Ship type', 'Reporting Period',
#        'Technical efficiency', 'Port of Registry', 'Home Port', 'Ice Class',
#        'DoC issue date', 'DoC expiry date', 'Verifier Number', 'Verifier Name',
#        'Verifier NAB', 'Verifier Address', 'Verifier City',
#        'Verifier Accreditation number', 'Verifier Country', 'A', 'B', 'C', 'D',
#        'Total fuel consumption [m tonnes]',
#        'Fuel consumptions assigned to On laden [m tonnes]',
#        'Total CO₂ emissions [m tonnes]',
#        'CO₂ emissions from all voyages between ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions from all voyages which departed from ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions from all voyages to ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions which occurred within ports under a MS jurisdiction at berth [m tonnes]',
#        'CO₂ emissions assigned to Passenger transport [m tonnes]',
# ...

# %%
df.describe()
# Out:
#          IMO Number  Reporting Period  Total fuel consumption [m tonnes]  \
# count  1.220400e+04           12204.0                       12204.000000
# mean   9.441852e+06            2019.0                        3820.366308
# std    2.917629e+05               0.0                        4722.112747
# min    5.383304e+06            2019.0                           0.000000
# 25%    9.302899e+06            2019.0                        1131.730000
# 50%    9.442762e+06            2019.0                        2198.420000
# 75%    9.645010e+06            2019.0                        4371.560000
# max    9.888807e+06            2019.0                       48449.600000
#
#        Fuel consumptions assigned to On laden [m tonnes]  \
# count                                        1418.000000
# mean                                         3659.239260
# std                                          4868.683128
# min                                             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# IMO Number                                                                                                                     0
# Name                                                                                                                           0
# Ship type                                                                                                                      0
# Reporting Period                                                                                                               0
# Technical efficiency                                                                                                         166
#                                                                                                                            ...
# CO₂ emissions per transport work (dwt) on laden voyages [g CO₂ / dwt carried · n miles]                                    12104
# ...

# %%
print(df['Ship type'].value_counts())
# Out:
# Bulk carrier                  3609
# Oil tanker                    1998
# Container ship                1831
# Chemical tanker               1354
# General cargo ship            1195
# Vehicle carrier                412
# Ro-pax ship                    391
# Gas carrier                    342
# Ro-ro ship                     275
# LNG carrier                    257
# Passenger ship                 179
# Refrigerated cargo carrier     145
# Other ship types               129
# Container/ro-ro cargo ship      76
# Combination carrier             11
# Name: Ship type, dtype: int64

# %%
df['Total fuel consumption [m tonnes]']
# Out:
# 0        7689.55
# 1        8458.51
# 2        1558.00
# 3        5187.27
# 4        1607.60
#           ...
# 12199     390.77
# 12200     314.92
# 12201     330.00
# 12202     185.88
# 12203     221.30
# Name: Total fuel consumption [m tonnes], Length: 12204, dtype: float64

# %%
df['Ship type']
# Out:
# 0            Passenger ship
# 1            Passenger ship
# 2               Ro-pax ship
# 3            Passenger ship
# 4          Other ship types
#                 ...
# 12199    General cargo ship
# 12200    General cargo ship
# 12201    General cargo ship
# 12202    General cargo ship
# 12203    General cargo ship
# Name: Ship type, Length: 12204, dtype: object

# %%
import seaborn as sns 
import matplotlib.pyplot as plt    
from warnings import filterwarnings 
fuel = df["Total fuel consumption [m tonnes]"]
ship = df["Ship type"]

# %%
sns.set_style('whitegrid') 
sns.distplot(df['Total fuel consumption [m tonnes]'],color ='red')
# Out:
# <AxesSubplot:xlabel='Total fuel consumption [m tonnes]'>

# %%
fig, ax = plt.subplots(figsize =(9, 7)) 
sns.violinplot( ax = ax, y = df["Total fuel consumption [m tonnes]"] )
# Out:
# <AxesSubplot:ylabel='Total fuel consumption [m tonnes]'>

# %%
x=[]
y=[]

# %%
x=list(ship)
y=list(fuel)

# %% [markdown]
# # scatter plot

# %%
plt.scatter(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 12204 artists>

# %%
co2=df["Total CO₂ emissions [m tonnes]"]
k=[]
k=list(co2)

# %%
plt.scatter(x,k)

# %%
plt.bar(x,k)
# Out:
# <BarContainer object of 12204 artists>

# %%
df.hist(figsize=(48,48))
plt.show()
# Out:
# C:\Users\DELL\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DELL\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8322 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# # import numpy as np
# # cor=df.corr()
# # #ns.heatmap(cor)
# # plt.figure(figsize=(15,15))
# # df_lt = cor.where(np.tril(np.ones(cor.shape)).astype(np.bool))
# # sns.heatmap(df_lt,cmap='Blues')
# # Correlation Heatmap
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# corr = df.corr()
# mask = np.triu(np.ones_like(corr, dtype=np.bool))
# f, ax = plt.subplots(figsize=(20, 20))
# cmap = sns.diverging_palette(250, 25, as_cmap=True)
# sns.heatmap(corr, mask=mask, cmap=cmap, vmax=None, center=0,square=True, annot=True, linewidths=.5, cbar_kws={"shrink": .9})

# %% [markdown]
# # find object datatype

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Name', 'Ship type', 'Technical efficiency', 'Port of Registry',
#        'Home Port', 'Ice Class', 'DoC issue date', 'DoC expiry date',
#        'Verifier Number', 'Verifier Name', 'Verifier NAB', 'Verifier Address',
#        'Verifier City', 'Verifier Accreditation number', 'Verifier Country',
#        'A', 'B', 'C', 'D',
#        'Annual average Fuel consumption per distance [kg / n mile]',
#        'Annual average Fuel consumption per transport work (mass) [g / m tonnes · n miles]',
#        'Annual average Fuel consumption per transport work (volume) [g / m³ · n miles]',
#        'Annual average Fuel consumption per transport work (dwt) [g / dwt carried · n miles]',
#        'Annual average Fuel consumption per transport work (pax) [g / pax · n miles]',
#        'Annual average Fuel consumption per transport work (freight) [g / m tonnes · n miles]',
#        'Annual average CO₂ emissions per distance [kg CO₂ / n mile]',
# ...

# %%
df['Name'] = df['Name'].fillna(df['Name'].mode()[0])
df['Ship type'] = df['Ship type'].fillna(df['Ship type'].mode()[0])
df['Technical efficiency'] = df['Technical efficiency'].fillna(df['Technical efficiency'].mode()[0])
df['Port of Registry'] = df['Port of Registry'].fillna(df['Port of Registry'].mode()[0])
df['Home Port'] = df['Home Port'].fillna(df['Home Port'].mode()[0])
df['Ice Class'] = df['Ice Class'].fillna(df['Ice Class'].mode()[0])
df['DoC issue date'] = df['DoC issue date'].fillna(df['DoC issue date'].mode()[0])
df['Verifier Number'] = df['Verifier Number'].fillna(df['Verifier Number'].mode()[0])
df['Verifier Name'] = df['Verifier Name'].fillna(df['Verifier Name'].mode()[0])
df['Verifier NAB'] = df['Verifier NAB'].fillna(df['Verifier NAB'].mode()[0])
df['Verifier Address'] = df['Verifier Address'].fillna(df['Verifier Address'].mode()[0])
df['Verifier City'] = df['Verifier City'].fillna(df['Verifier City'].mode()[0])
df['Verifier Accreditation number'] = df['Verifier Accreditation number'].fillna(df['Verifier Accreditation number'].mode()[0])
df['Verifier Country'] = df['Verifier Country'].fillna(df['Verifier Country'].mode()[0])
df['A'] = df['A'].fillna(df['A'].mode()[0])
df['B'] = df['B'].fillna(df['B'].mode()[0])
df['C'] = df['C'].fillna(df['C'].mode()[0])
df['D'] = df['D'].fillna(df['D'].mode()[0])
df['Annual average Fuel consumption per distance [kg / n mile]'] = df['Annual average Fuel consumption per distance [kg / n mile]'].fillna(df['Annual average Fuel consumption per distance [kg / n mile]'].mode()[0])
df['Annual average Fuel consumption per transport work (mass) [g / m tonnes · n miles]'] = df['Annual average Fuel consumption per transport work (mass) [g / m tonnes · n miles]'].fillna(df['Annual average Fuel consumption per transport work (mass) [g / m tonnes · n miles]'].mode()[0])
df['Annual average Fuel consumption per transport work (volume) [g / m³ · n miles]'] = df['Annual average Fuel consumption per transport work (volume) [g / m³ · n miles]'].fillna(df['Annual average Fuel consumption per transport work (volume) [g / m³ · n miles]'].mode()[0])
df['Annual average Fuel consumption per transport work (dwt) [g / dwt carried · n miles]'] = df['Annual average Fuel consumption per transport work (dwt) [g / dwt carried · n miles]'].fillna(df['Annual average Fuel consumption per transport work (dwt) [g / dwt carried · n miles]'].mode()[0])
df['Annual average Fuel consumption per transport work (pax) [g / pax · n miles]'] = df['Annual average Fuel consumption per transport work (pax) [g / pax · n miles]'].fillna(df['Annual average Fuel consumption per transport work (pax) [g / pax · n miles]'].mode()[0])
df['Annual average Fuel consumption per transport work (freight) [g / m tonnes · n miles]'] = df['Annual average Fuel consumption per transport work (freight) [g / m tonnes · n miles]'].fillna(df['Annual average Fuel consumption per transport work (freight) [g / m tonnes · n miles]'].mode()[0])
df['Annual average CO₂ emissions per distance [kg CO₂ / n mile]'] = df['Annual average CO₂ emissions per distance [kg CO₂ / n mile]'].fillna(df['Annual average CO₂ emissions per distance [kg CO₂ / n mile]'].mode()[0])
df['Annual average CO₂ emissions per transport work (mass) [g CO₂ / m tonnes · n miles]'] = df['Annual average CO₂ emissions per transport work (mass) [g CO₂ / m tonnes · n miles]'].fillna(df['Annual average CO₂ emissions per transport work (mass) [g CO₂ / m tonnes · n miles]'].mode()[0])
df['Annual average CO₂ emissions per transport work (volume) [g CO₂ / m³ · n miles]'] = df['Annual average CO₂ emissions per transport work (volume) [g CO₂ / m³ · n miles]'].fillna(df['Annual average CO₂ emissions per transport work (volume) [g CO₂ / m³ · n miles]'].mode()[0])
df['Annual average CO₂ emissions per transport work (dwt) [g CO₂ / dwt carried · n miles]'] = df['Annual average CO₂ emissions per transport work (dwt) [g CO₂ / dwt carried · n miles]'].fillna(df['Annual average CO₂ emissions per transport work (dwt) [g CO₂ / dwt carried · n miles]'].mode()[0])
df['Annual average CO₂ emissions per transport work (pax) [g CO₂ / pax · n miles]'] = df['Annual average CO₂ emissions per transport work (pax) [g CO₂ / pax · n miles]'].fillna(df['Annual average CO₂ emissions per transport work (pax) [g CO₂ / pax · n miles]'].mode()[0])
df['Annual average CO₂ emissions per transport work (freight) [g CO₂ / m tonnes · n miles]'] = df['Annual average CO₂ emissions per transport work (freight) [g CO₂ / m tonnes · n miles]'].fillna(df['Annual average CO₂ emissions per transport work (freight) [g CO₂ / m tonnes · n miles]'].mode()[0])
df['Unnamed: 47'] = df['Unnamed: 47'].fillna(df['Unnamed: 47'].mode()[0])
df['Fuel consumption per distance on laden voyages [kg / n mile]'] = df['Fuel consumption per distance on laden voyages [kg / n mile]'].fillna(df['Fuel consumption per distance on laden voyages [kg / n mile]'].mode()[0])
df['Fuel consumption per transport work (mass) on laden voyages [g / m tonnes · n miles]'] = df['Fuel consumption per transport work (mass) on laden voyages [g / m tonnes · n miles]'].fillna(df['Fuel consumption per transport work (mass) on laden voyages [g / m tonnes · n miles]'].mode()[0])
df['Fuel consumption per transport work (dwt) on laden voyages [g / dwt carried · n miles]'] = df['Fuel consumption per transport work (dwt) on laden voyages [g / dwt carried · n miles]'].fillna(df['Fuel consumption per transport work (dwt) on laden voyages [g / dwt carried · n miles]'].mode()[0])
df['CO₂ emissions per distance on laden voyages [kg CO₂ / n mile]'] = df['CO₂ emissions per distance on laden voyages [kg CO₂ / n mile]'].fillna(df['CO₂ emissions per distance on laden voyages [kg CO₂ / n mile]'].mode()[0])
df['CO₂ emissions per transport work (mass) on laden voyages [g CO₂ / m tonnes · n miles]'] = df['CO₂ emissions per transport work (mass) on laden voyages [g CO₂ / m tonnes · n miles]'].fillna(df['CO₂ emissions per transport work (mass) on laden voyages [g CO₂ / m tonnes · n miles]'].mode()[0])
df['CO₂ emissions per transport work (dwt) on laden voyages [g CO₂ / dwt carried · n miles]'] = df['CO₂ emissions per transport work (dwt) on laden voyages [g CO₂ / dwt carried · n miles]'].fillna(df['CO₂ emissions per transport work (dwt) on laden voyages [g CO₂ / dwt carried · n miles]'].mode()[0])
df['Additional information to facilitate the understanding of the reported average operational energy efficiency indicators'] = df['Additional information to facilitate the understanding of the reported average operational energy efficiency indicators'].fillna(df['Additional information to facilitate the understanding of the reported average operational energy efficiency indicators'].mode()[0])

# %%
df = df.dropna(axis=1)
df
# Out:
#        IMO Number           Name           Ship type  Reporting Period  \
# 0         5383304        ASTORIA      Passenger ship              2019
# 1         6417097     MARCO POLO      Passenger ship              2019
# 2         6511128     RED STAR 1         Ro-pax ship              2019
# 3         6602898  OCEAN MAJESTY      Passenger ship              2019
# 4         6703343       EQUALITY    Other ship types              2019
# ...           ...            ...                 ...               ...
# 12199     9873101         IDEL 2  General cargo ship              2019
# 12200     9873113         IDEL 3  General cargo ship              2019
# 12201     9873125    ANDREY ZUEV  General cargo ship              2019
# 12202     9888792    POLA HARITA  General cargo ship              2019
# 12203     9888807  POLA PELAGEYA  General cargo ship              2019
#
#          Technical efficiency Port of Registry Home Port Ice Class  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lencoders = {}
for col in df.select_dtypes(include=['object']).columns:
    lencoders[col] = LabelEncoder()
    df[col] = lencoders[col].fit_transform(df[col])

# %%
df.fillna(df.mean(), inplace=True)

# %%
import seaborn as sns
sns.boxplot(df['Total CO₂ emissions [m tonnes]'])
# Out:
# <AxesSubplot:xlabel='Total CO₂ emissions [m tonnes]'>
# C:\Users\DELL\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DELL\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8322 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df.isnull().sum()
# Out:
# IMO Number                                                                                                                 0
# Name                                                                                                                       0
# Ship type                                                                                                                  0
# Reporting Period                                                                                                           0
# Technical efficiency                                                                                                       0
# Port of Registry                                                                                                           0
# Home Port                                                                                                                  0
# ...

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# IMO Number                                                                                                                 342110.7500
# Name                                                                                                                         6014.5000
# Ship type                                                                                                                       8.0000
# Reporting Period                                                                                                                0.0000
# Technical efficiency                                                                                                         1838.2500
# Port of Registry                                                                                                               80.0000
# Home Port                                                                                                                       0.0000
# ...

# %%
# Removing outliers from the dataset
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# (3372, 48)

# %%
import numpy as np
cor=df.corr()
#sns.heatmap(cor)
plt.figure(figsize=(15,15))
df_lt = cor.where(np.tril(np.ones(cor.shape)).astype(np.bool))
sns.heatmap(df_lt,cmap='Blues')
# Correlation Heatmap
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# corr = df.corr()
# mask = np.triu(np.ones_like(corr, dtype=np.bool))
# f, ax = plt.subplots(figsize=(30, 30))
# cmap = sns.diverging_palette(250, 25, as_cmap=True)
# sns.heatmap(corr, mask=mask, cmap=cmap, vmax=None, center=0,square=True, annot=True, linewidths=.5)
# Out:
# C:\Users\DELL\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DELL\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8322 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:>

# %%
print(df.isnull().sum())
# Out:
# IMO Number                                                                                                                 0
# Name                                                                                                                       0
# Ship type                                                                                                                  0
# Reporting Period                                                                                                           0
# Technical efficiency                                                                                                       0
# Port of Registry                                                                                                           0
# Home Port                                                                                                                  0
# ...

# %%
from sklearn import preprocessing
r_scaler = preprocessing.MinMaxScaler()
r_scaler.fit(df)
modified_data = pd.DataFrame(r_scaler.transform(df), index=df.index, columns=df.columns)

# %%
# Feature Importance using Filter Method (f_regression)
from sklearn.feature_selection import SelectKBest, f_regression
X = modified_data.loc[:,modified_data.columns!='Total fuel consumption [m tonnes]']
y = modified_data[['Total fuel consumption [m tonnes]']]
selector = SelectKBest(f_regression, k=15)
selector.fit(X, y)
X_new = selector.transform(X)
print(X.columns[selector.get_support(indices=True)])
# Out:
# Index(['Ship type', 'Technical efficiency', 'Port of Registry',
#        'Verifier City', 'Total CO₂ emissions [m tonnes]',
#        'CO₂ emissions from all voyages between ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions from all voyages which departed from ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions from all voyages to ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions which occurred within ports under a MS jurisdiction at berth [m tonnes]',
#        'Annual Total time spent at sea [hours]',
#        'Annual average Fuel consumption per distance [kg / n mile]',
#        'Annual average Fuel consumption per transport work (mass) [g / m tonnes · n miles]',
#        'Annual average CO₂ emissions per distance [kg CO₂ / n mile]',
#        'Annual average CO₂ emissions per transport work (mass) [g CO₂ / m tonnes · n miles]',
#        'Total time spent at sea [hours]'],
#       dtype='object')
# ...

# %%
# # Feature Importance using Filter Method (f_regression)
# from sklearn.feature_selection import SelectKBest, f_regression
# X = modified_data.loc[:,modified_data.columns!='Total CO₂ emissions [m tonnes]']
# y = modified_data[['Total CO₂ emissions [m tonnes]']]
# selector = SelectKBest(f_regression, k=15)
# selector.fit(X, y)
# X_new = selector.transform(X)
# print(X.columns[selector.get_support(indices=True)])

# %%
# X = df.iloc[:, 1:48].values
# y = df.iloc[:, 22].values

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.30, random_state=1)

# %%
# from sklearn.ensemble import RandomForestRegressor 
# regressor = RandomForestRegressor(n_estimators=10, random_state=1)
# regressor.fit(X,y)

# %%
# X_grid = np.arange(min(X), max(X),0.01)
# X_grid = X_grid.reshape((len(X_grid), 1))
# plt.scatter(X, y, color = 'red')
# plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
# plt.title('Random Forest Regression Model')
# plt.xlabel('other features')
# plt.ylabel('Fuel Consumption')
# plt.show()

# %% [markdown]
# # Linear Regression

# %%
# features = df[['Ship type','Total CO₂ emissions [m tonnes]',
#        'Annual average Fuel consumption per distance [kg / n mile]',
#        'Annual average Fuel consumption per transport work (mass) [g / m tonnes · n miles]',
#        'Annual average Fuel consumption per transport work (volume) [g / m³ · n miles]',
#        'Annual average Fuel consumption per transport work (pax) [g / pax · n miles]',
#        'Annual average Fuel consumption per transport work (freight) [g / m tonnes · n miles]',
#        'Annual average CO₂ emissions per distance [kg CO₂ / n mile]',
#        'Annual average CO₂ emissions per transport work (volume) [g CO₂ / m³ · n miles]',
#        'Annual average CO₂ emissions per transport work (dwt) [g CO₂ / dwt carried · n miles]',
#        'Annual average CO₂ emissions per transport work (pax) [g CO₂ / pax · n miles]',
#        'Annual average CO₂ emissions per transport work (freight) [g CO₂ / m tonnes · n miles]']]
# target = df['Total fuel consumption [m tonnes]']

# # Split into test and train
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.25, random_state=1)

# # Normalize Features
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.fit_transform(X_test)

# %%
# from sklearn.linear_model import LinearRegression
# regression_model = LinearRegression()
# # Fit the data(train the model)
# regression_model.fit(X_train, y_train)
# # Predict
# y_predic = regression_model.predict(X_test)

# %%
# from sklearn import metrics

# print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_predic))
# print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_predic))
# print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_predic)))

# %%
# from sklearn.metrics import r2_score
# from sklearn.metrics import mean_squared_error
# rmse = mean_squared_error(y_test, y_predic)
# r2 = r2_score(y_test, y_predic)
# print(r2)

# %%
# features = df[['Ship type',
#        'CO₂ emissions from all voyages between ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions from all voyages which departed from ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions from all voyages to ports under a MS jurisdiction [m tonnes]',
#        'Annual average Fuel consumption per transport work (pax) [g / pax · n miles]',
#        'Annual average Fuel consumption per transport work (freight) [g / m tonnes · n miles]',
#        'Annual average CO₂ emissions per distance [kg CO₂ / n mile]',
#        'Annual average CO₂ emissions per transport work (pax) [g CO₂ / pax · n miles]',
#        'Annual average CO₂ emissions per transport work (freight) [g CO₂ / m tonnes · n miles]']]
# target = df['Total CO₂ emissions [m tonnes]']

# # Split into test and train
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.25, random_state=12345)

# # Normalize Features
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.fit_transform(X_test)

# %%
# y_train_pred = regression_model.predict(X_train)
# y_test_pred = regression_model.predict(X_test)

# %%
# from sklearn import metrics

# print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_predic))
# print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_predic))
# print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_predic)))

# %%
# from sklearn.metrics import r2_score
# from sklearn.metrics import mean_squared_error
# rmse = mean_squared_error(y_test, y_predic)
# r2 = r2_score(y_test, y_predic)
# print(r2)

# %%
# plt.scatter(y_train_pred,  y_train_pred - y_train,
#             c='blue', marker='o', label='Training data')
# plt.scatter(y_test_pred,  y_test_pred - y_test,
#             c='lightgreen', marker='s', label='Test data')
# plt.xlabel('Predicted values')
# plt.ylabel('Residuals')
# plt.legend(loc='upper left')
# plt.hlines(y=0, xmin=-10, xmax=50, lw=2, color='red')
# plt.xlim([-10, 50])
# plt.tight_layout()

# # plt.savefig('./figures/slr_residuals.png', dpi=300)
# plt.show()

# %%
# from sklearn.metrics import r2_score
# from sklearn.metrics import mean_squared_error

# print('MSE train: %.3f, test: %.3f' % (
#         mean_squared_error(y_train, y_train_pred),
#         mean_squared_error(y_test, y_test_pred)))
# print('R^2 train: %.3f, test: %.3f' % (
#         r2_score(y_train, y_train_pred),
#         r2_score(y_test, y_test_pred)))

# %%
# def plot_roc_cur(fper, tper):  
#     plt.plot(fper, tper, color='orange', label='ROC')
#     plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
#     plt.title('Receiver Operating Characteristic (ROC) Curve')
#     plt.legend()
#     plt.show()

# %%
# df.select_dtypes(include=['object']).columns

# %%
# from sklearn.linear_model import LinearRegression
# X = df['Total fuel consumption [m tonnes]'].values.reshape(-1, 1)  # values converts it into a numpy array
# Y = df['Total CO₂ emissions [m tonnes]'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
# linear_regressor = LinearRegression()  # create object for the class
# linear_regressor.fit(X, Y)  # perform linear regression
# Y_pred = linear_regressor.predict(X)  # make predictions

# %%
# plt.scatter(X, Y)
# plt.plot(X, Y_pred, color='red')
# plt.show()

# %%
# from sklearn.preprocessing import PolynomialFeatures
# pr = PolynomialFeatures(degree = 2)
# X_poly = pr.fit_transform(X)
# pr.fit(X_poly, Y)
# lin_reg = LinearRegression()
# lin_reg.fit(X_poly, Y)
# plt.scatter(X, Y)
# plt.scatter(X, lin_reg.predict(pr.fit_transform(X)))
# plt.show()

# %%
# features = df[['IMO Number',                                                                                                                 
# 'Name',                                                                                                                  
# 'Ship type',                                                                                                                 
# 'Reporting Period',                                                                                                           
# 'Technical efficiency',                                                                                                      
# 'Port of Registry',                                                                                                         
# 'Home Port',                                                                                                                  
# 'Ice Class',                                                                                                                  
# 'DoC issue date',                                                                                                             
# 'Verifier Number',                                                                                                            
# 'Verifier Name',                                                                                                              
# 'Verifier NAB',                                                                                                              
# 'Verifier Address',                                                                                                           
# 'Verifier City',                                                                                                              
# 'Verifier Accreditation number',                                                                                              
# 'Verifier Country',                                                                                                           
# 'A',                                                                                                                          
# 'B' ,                                                                                                                         
# 'C',                                                                                                                          
# 'D',                                                                                                                          
# 'Total fuel consumption [m tonnes]',                                                                                          
# 'Total CO₂ emissions [m tonnes]',                                                                                                                                
# 'Annual Total time spent at sea [hours]',                                                                                     
# 'Annual average Fuel consumption per distance [kg / n mile]',                                                                 
# 'Annual average Fuel consumption per transport work (mass) [g / m tonnes · n miles]',                                         
# 'Annual average Fuel consumption per transport work (volume) [g / m³ · n miles]',                                             
# 'Annual average Fuel consumption per transport work (dwt) [g / dwt carried · n miles]',                                       
# 'Annual average Fuel consumption per transport work (pax) [g / pax · n miles]',                                               
# 'Annual average Fuel consumption per transport work (freight) [g / m tonnes · n miles]',                                      
# 'Annual average CO₂ emissions per distance [kg CO₂ / n mile]',                                                                
# 'Annual average CO₂ emissions per transport work (mass) [g CO₂ / m tonnes · n miles]',                                        
# 'Annual average CO₂ emissions per transport work (volume) [g CO₂ / m³ · n miles]',                                            
# 'Annual average CO₂ emissions per transport work (dwt) [g CO₂ / dwt carried · n miles]',                                      
# 'Annual average CO₂ emissions per transport work (pax) [g CO₂ / pax · n miles]',                                              
# 'Annual average CO₂ emissions per transport work (freight) [g CO₂ / m tonnes · n miles]',                                     
# 'Total time spent at sea [hours]',                                                                                            
# 'Unnamed: 47',                                                                                                                
# 'Fuel consumption per distance on laden voyages [kg / n mile]',                                                              
# 'Fuel consumption per transport work (mass) on laden voyages [g / m tonnes · n miles]',                                      
# 'Fuel consumption per transport work (dwt) on laden voyages [g / dwt carried · n miles]',                                    
# 'CO₂ emissions per distance on laden voyages [kg CO₂ / n mile]',                                                              
# 'CO₂ emissions per transport work (mass) on laden voyages [g CO₂ / m tonnes · n miles]',                                      
# 'CO₂ emissions per transport work (dwt) on laden voyages [g CO₂ / dwt carried · n miles]',                                    
# 'Additional information to facilitate the understanding of the reported average operational energy efficiency indicators'    ]]
# target = df['Total fuel consumption [m tonnes]']

# # Split into test and train
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.30, random_state=12345)

# # Normalize Features
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.fit_transform(X_test)

# %%
# from sklearn.linear_model import LinearRegression
# regression_model = LinearRegression()
# # Fit the data(train the model)
# regression_model.fit(X_train, y_train)
# # Predict
# y_predic = regression_model.predict(X_test)

# %%
# plt.scatter(y_train_pred,  y_train_pred - y_train,
#             c='blue', marker='o', label='Training data')
# plt.scatter(y_test_pred,  y_test_pred - y_test,
#             c='lightgreen', marker='s', label='Test data')
# plt.xlabel('Predicted values')
# plt.ylabel('Residuals')
# plt.legend(loc='upper left')
# plt.hlines(y=-10, xmin=-10, xmax=50, lw=2, color='red')
# plt.xlim([-0, 50])
# plt.tight_layout()

# # plt.savefig('./figures/slr_residuals.png', dpi=300)
# plt.show()

# %%
# from sklearn import metrics

# print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_predic))
# print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_predic))
# print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_predic)))

# %%
# from sklearn.metrics import r2_score
# from sklearn.metrics import mean_squared_error

# rmse = mean_squared_error(y_test, y_predic)
# r2 = r2_score(y_test, y_predic)
# print(r2)

# %% [markdown]
# # Random Forest:

# %%
X = df[['Ship type',
        'CO₂ emissions from all voyages between ports under a MS jurisdiction [m tonnes]',
       'CO₂ emissions from all voyages which departed from ports under a MS jurisdiction [m tonnes]',
       'CO₂ emissions from all voyages to ports under a MS jurisdiction [m tonnes]',
       'Annual average Fuel consumption per distance [kg / n mile]',
       'Annual average Fuel consumption per transport work (mass) [g / m tonnes · n miles]',
       'Annual average Fuel consumption per transport work (volume) [g / m³ · n miles]',
       'Annual average Fuel consumption per transport work (pax) [g / pax · n miles]',
       'Annual average Fuel consumption per transport work (freight) [g / m tonnes · n miles]',
       'Annual average CO₂ emissions per distance [kg CO₂ / n mile]',
       'Annual average CO₂ emissions per transport work (volume) [g CO₂ / m³ · n miles]',
       'Annual average CO₂ emissions per transport work (dwt) [g CO₂ / dwt carried · n miles]',
       'Annual average CO₂ emissions per transport work (pax) [g CO₂ / pax · n miles]',
       'Annual average CO₂ emissions per transport work (freight) [g CO₂ / m tonnes · n miles]']].values

y = df['Total fuel consumption [m tonnes]'].values
# Split into test and train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30, random_state=12345)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100,random_state=1)
regressor.fit(X_train,y_train)
y_predic = regressor.predict(X_test)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_predic))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_predic))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_predic)))
# Out:
# Mean Absolute Error: 99.10496778656122
# Mean Squared Error: 22884.69479669204
# Root Mean Squared Error: 151.276881236665

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(y_test, y_predic)
r2 = r2_score(y_test, y_predic)
print(r2)
# Out:
# 0.9886375314799648

# %%
# X_grid = np.arange(min(X), max(X), 0.01)
# X_grid = X_grid.reshape((len(X_grid), 1))
# plt.scatter(X, y, color = 'red')
# plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
# plt.title('Check It (Random Forest Regression Model)')
# plt.xlabel('Position level')
# plt.ylabel('Salary')
# plt.show()

# %% [markdown]
# # Decision Tree:

# %%
# from sklearn.tree import DecisionTreeRegressor
# regressor = DecisionTreeRegressor()
# regressor.fit(X_train, y_train)

# %%
# y_pred = regressor.predict(X_test)

# %%
# modified_data=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
# modified_data

# %%
# from sklearn import metrics

# print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
# print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
# print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %%
# from sklearn.metrics import r2_score
# from sklearn.metrics import mean_squared_error

# rmse = mean_squared_error(y_test, y_pred)
# r2 = r2_score(y_test, y_pred)
# print(r2)

# %% [markdown]
# # Lasso Regression:

# %%
# from sklearn.linear_model import Lasso

# reg = Lasso(alpha=0.5)
# reg.fit(X_train, y_train)

# %%
#  y_pred = reg.predict(X_test)

# %%
# from sklearn import metrics

# print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
# print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
# print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %%
# from sklearn.metrics import r2_score
# from sklearn.metrics import mean_squared_error

# rmse = mean_squared_error(y_test, y_pred)
# r2 = r2_score(y_test, y_pred)
# print(r2)

# %% [markdown]
# # Ridge Regression:

# %%
# from sklearn.linear_model import Ridge
# ridge2 = Ridge(alpha = 4, normalize = True)
# ridge2.fit(X_train, y_train)

# %%
#  y_predic = ridge2.predict(X_test)

# %%
# from sklearn import metrics

# print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_predic))
# print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_predic))
# print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_predic)))

# %%
# from sklearn.metrics import r2_score
# from sklearn.metrics import mean_squared_error

# rmse = mean_squared_error(y_test, y_predic)
# r2 = r2_score(y_test, y_predic)
# print(r2)
